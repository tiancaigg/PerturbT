# %%
try:
    import flash_attn
    print(f"flash-attn version: {flash_attn.__version__}")
except ImportError:
    print("flash-attn not installed.")
# Out:
# flash-attn not installed.

# %%
import torch

# Check if xformers is available through PyTorch's backend
from torch.nn.attention import SDPBackend, sdpa_kernel

# This will print which backends are available on your V100
print(f"Xformers available: {torch.cuda.is_available() and hasattr(torch, 'xformers')}") 
# Note: Newer PyTorch versions might not show it as a 'torch' attribute, 
# but will use it via the sdpa_kernel.
# Out:
# Xformers available: False
